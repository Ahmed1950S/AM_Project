# %% [markdown]
# ### SAAM Part I — Minimum Variance Portfolio (EUR Region)
# ### This notebook implements the Systematic Asset Allocation Methodology (SAAM) for EUR region portfolios.
# ### It covers minimum variance optimization, carbon-aware portfolios, and net-zero glide paths.

# %% [markdown]
# ## Setup and Configuration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from scipy.optimize import minimize, linprog
from IPython.display import display, HTML

# %% [markdown]
# > ### Methodological deviation #1 — Stale-price threshold
# >
# > The project says the stale-price exclusion threshold is *"e.g., 50%"*, leaving room for judgement.
# > We tighten it to **30%** as a more conservative liquidity filter.
# >
# > **Sensitivity check:** changing 30% → 50% adds **at most 1 firm per year** to the universe across 2013–2024.
# > The impact on the optimal MV portfolio is materially zero.

# %%
# ─── Configuration ────────────────────────────────────────────────────────────
REGION = "EUR"
START_YEAR = 2013
END_YEAR = 2024
ESTIM_YEARS = 10
MIN_OBS = 36
STALE_THR = 0.30
LOW_FLOOR = 0.50
DATA_PATH = "Data_2026/"
TEMPLATE_PATH = "Data_2026/Template_for_Part_I-SAAM.xlsx"
OUT = "Output_2026/"

# %% [markdown]
# ## 1. Load Raw Data

# %%
static = pd.read_excel(DATA_PATH + "Static_2025.xlsx")
ri_m_raw = pd.read_excel(DATA_PATH + "DS_RI_T_USD_M_2025.xlsx", sheet_name="RI")
mv_m_raw = pd.read_excel(DATA_PATH + "DS_MV_T_USD_M_2025.xlsx", sheet_name="MV")
ri_y_raw = pd.read_excel(DATA_PATH + "DS_RI_T_USD_Y_2025.xlsx", sheet_name="RI")
mv_y_raw = pd.read_excel(DATA_PATH + "DS_MV_T_USD_Y_2025.xlsx", sheet_name="MV")
co2_s1_raw = pd.read_excel(DATA_PATH + "DS_CO2_SCOPE_1_Y_2025.xlsx", sheet_name="Scope1")
co2_s2_raw = pd.read_excel(DATA_PATH + "DS_CO2_SCOPE_2_Y_2025.xlsx", sheet_name="Scope2")
rev_raw = pd.read_excel(DATA_PATH + "DS_REV_Y_2025.xlsx", sheet_name="REV")
rf_raw = pd.read_excel(DATA_PATH + "Risk_Free_Rate_2025.xlsx",
                       sheet_name="F-F_Research_Data_Factors")

_summary = pd.DataFrame({
    "Dataset": ["Static","RI monthly","MV monthly","RI annual","MV annual",
                "CO2 Scope 1","CO2 Scope 2","Revenue","Risk-Free Rate"],
    "Shape": [str(static.shape), str(ri_m_raw.shape), str(mv_m_raw.shape),
              str(ri_y_raw.shape), str(mv_y_raw.shape),
              str(co2_s1_raw.shape), str(co2_s2_raw.shape),
              str(rev_raw.shape), str(rf_raw.shape)]
})
display(_summary.style
        .set_caption("Loaded datasets")
        .hide(axis="index")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_84dee caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_84dee">
#   <caption>Loaded datasets</caption>
#   <thead>
#     <tr>
#       <th id="T_84dee_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_84dee_level0_col1" class="col_heading level0 col1" >Shape</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_84dee_row0_col0" class="data row0 col0" >Static</td>
#       <td id="T_84dee_row0_col1" class="data row0 col1" >(2545, 4)</td>
#     </tr>
#     <tr>
#       <td id="T_84dee_row1_col0" class="data row1 col0" >RI monthly</td>
#       <td id="T_84dee_row1_col1" class="data row1 col1" >(2609, 316)</td>
#     </tr>
#     <tr>
#       <td id="T_84dee_row2_col0" class="data row2 col0" >MV monthly</td>
#       <td id="T_84dee_row2_col1" class="data row2 col1" >(2609, 316)</td>
#     </tr>
#     <tr>
#       <td id="T_84dee_row3_col0" class="data row3 col0" >RI annual</td>
# ...

# %% [markdown]
# ## 2. Clean Datastream Format

# %%
def clean_ds(df, valid_isins):
    """Drop error rows, filter to valid ISINs, set ISIN as index, coerce to numeric."""
    df = df.dropna(subset=["ISIN"]).copy()
    df = df[~df["ISIN"].astype(str).str.contains("ER:", na=False)]
    df = df[df["ISIN"].isin(valid_isins)]
    names = df.set_index("ISIN")["NAME"]
    data_cols = [c for c in df.columns if c not in ["NAME", "ISIN"] and c is not None]
    data = df.set_index("ISIN")[data_cols].apply(pd.to_numeric, errors="coerce")
    new_cols = []
    for c in data.columns:
        if hasattr(c, "year") and not isinstance(c, (int, np.integer)):
            new_cols.append(pd.Timestamp(c))
        else:
            new_cols.append(c)
    data.columns = new_cols
    return data, names


eur_isins = set(static.loc[static["Region"] == REGION, "ISIN"])

ri_m, firm_names = clean_ds(ri_m_raw, eur_isins)
mv_m, _ = clean_ds(mv_m_raw, eur_isins)
ri_y, _ = clean_ds(ri_y_raw, eur_isins)
mv_y, _ = clean_ds(mv_y_raw, eur_isins)
co2_s1, _ = clean_ds(co2_s1_raw, eur_isins)
co2_s2, _ = clean_ds(co2_s2_raw, eur_isins)
rev, _ = clean_ds(rev_raw, eur_isins)

isin_name = firm_names.to_dict()
display(HTML(f'<div style="padding:6px 0;font-size:14px">'
             f'✓ EUR universe: <b style="color:#1a6b1a">{len(eur_isins)} ISINs</b>'
             f' | <b>{ri_m.shape[0]}</b> firms loaded</div>'))
# Out:
# <div style="padding:6px 0;font-size:14px">✓ EUR universe: <b style="color:#1a6b1a">633 ISINs</b> | <b>633</b> firms loaded</div>

# %% [markdown]
# ## 3. Build Date Lists

# %%
monthly_all = sorted([c for c in ri_m.columns if isinstance(c, pd.Timestamp)
                      and pd.Timestamp("2000-01-01") <= c <= pd.Timestamp("2025-12-31")])
annual_all = sorted([c for c in ri_y.columns if isinstance(c, (int, np.integer))])

ri_m = ri_m[monthly_all]
mv_m = mv_m[[c for c in monthly_all if c in mv_m.columns]]
ri_y = ri_y[[c for c in annual_all if c in ri_y.columns]]
mv_y = mv_y[[c for c in annual_all if c in mv_y.columns]]
co2_s1 = co2_s1[[c for c in annual_all if c in co2_s1.columns]]
co2_s2 = co2_s2[[c for c in annual_all if c in co2_s2.columns]]
rev = rev[[c for c in annual_all if c in rev.columns]]

_monthly_idx = {t: i for i, t in enumerate(monthly_all)}


def months_of(Y):
    return [c for c in monthly_all if c.year == Y]


def estim_window(Y):
    return [c for c in monthly_all
            if (Y - ESTIM_YEARS + 1, 1) <= (c.year, c.month) <= (Y, 12)]


_months_of = {Y: months_of(Y) for Y in range(START_YEAR - 1, END_YEAR + 2)}
_estim_window = {Y: estim_window(Y) for Y in range(START_YEAR, END_YEAR + 1)}

ew2013 = _estim_window[2013]
f"({ew2013[0].strftime('%Y-%m')} to {ew2013[-1].strftime('%Y-%m')})"
assert len(ew2013) == 120, f"Expected 120, got {len(ew2013)}"

# %% [markdown]
# ## 4. Risk-Free Rate

# %%
rf_raw.columns = ["YYYYMM", "RF_pct"]
rf_raw = rf_raw.dropna(subset=["YYYYMM"])
rf_raw["date"] = pd.to_datetime(rf_raw["YYYYMM"].astype(int).astype(str), format="%Y%m")
rf_raw["date"] = rf_raw["date"] + pd.offsets.MonthEnd(0)
rf_mon = rf_raw.set_index("date")["RF_pct"] / 100
rf_mon = rf_mon.squeeze()
rf_mon.name = "RF"

f"{rf_mon.index.max().strftime('%Y-%m')}"
# Out:
# '2025-12'

# %% [markdown]
# ## 5. Price Cleaning

# %%
n_low = ((ri_m > 0) & (ri_m < LOW_FLOOR)).sum().sum()
ri_m[ri_m < LOW_FLOOR] = np.nan

def forward_fill_internal(row):
    fv = row.first_valid_index()
    lv = row.last_valid_index()
    if fv is None or lv is None:
        return row
    cols = list(row.index)
    start = cols.index(fv)
    end = cols.index(lv)
    row.iloc[start:end + 1] = row.iloc[start:end + 1].ffill()
    return row


ri_before = ri_m.isna().sum().sum()
ri_m = ri_m.apply(forward_fill_internal, axis=1)
n_filled = ri_before - ri_m.isna().sum().sum()

cutoff = pd.Timestamp("2025-12-31")
last_valid = {}
for isin in ri_m.index:
    lv = ri_m.loc[isin].last_valid_index()
    if lv is not None and isinstance(lv, pd.Timestamp) and lv < cutoff:
        last_valid[isin] = lv

ret_m = ri_m.pct_change(axis=1)

for isin, ddate in last_valid.items():
    if ddate not in _monthly_idx:
        continue
    idx = _monthly_idx[ddate]
    if idx + 1 < len(monthly_all):
        ret_m.at[isin, monthly_all[idx + 1]] = -1.0
        for k in range(idx + 2, len(monthly_all)):
            ret_m.at[isin, monthly_all[k]] = np.nan

ret_m = ret_m.iloc[:, 1:]

n_delist = (ret_m == -1.0).sum().sum()

# Forward fill carbon data
co2_s1 = co2_s1.ffill(axis=1)
co2_s2 = co2_s2.ffill(axis=1)
rev = rev.ffill(axis=1)
display(pd.DataFrame.from_dict({
    "Prices below floor → NaN": n_low,
    "Internal gaps forward-filled": n_filled,
    "Firms with potential delisting": len(last_valid),
    "−100% delisting returns applied": n_delist,
}, orient="index", columns=["Count"])
.style.set_caption("Price cleaning summary")
.set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_e565e caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_e565e">
#   <caption>Price cleaning summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e565e_level0_col0" class="col_heading level0 col0" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e565e_level0_row0" class="row_heading level0 row0" >Prices below floor → NaN</th>
#       <td id="T_e565e_row0_col0" class="data row0 col0" >687</td>
#     </tr>
#     <tr>
#       <th id="T_e565e_level0_row1" class="row_heading level0 row1" >Internal gaps forward-filled</th>
#       <td id="T_e565e_row1_col0" class="data row1 col0" >147</td>
#     </tr>
#     <tr>
#       <th id="T_e565e_level0_row2" class="row_heading level0 row2" >Firms with potential delisting</th>
#       <td id="T_e565e_row2_col0" class="data row2 col0" >66</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## 6. Investment Set (Universe) Construction

# %%
def get_universe(Y):
    """Build investment set for allocation at end of year Y."""
    dec_cols = [c for c in monthly_all if c.year == Y and c.month == 12]
    if not dec_cols:
        return []
    dec_Y = dec_cols[0]

    win = _estim_window[Y]
    win_ret = [c for c in win if c in ret_m.columns]
    R_win = ret_m.reindex(columns=win_ret)

    out = []
    for isin in ri_m.index:
        if pd.isna(ri_m.at[isin, dec_Y]):
            continue
        if isin not in R_win.index:
            continue
        row = R_win.loc[isin]
        n_valid = row.notna().sum()
        if n_valid < MIN_OBS:
            continue
        n_zero = ((row == 0) | (row.abs() < 1e-10)).sum()
        if (n_zero / n_valid) > STALE_THR:
            continue
        has_s1 = Y in co2_s1.columns and pd.notna(co2_s1.at[isin, Y]) if isin in co2_s1.index else False
        has_s2 = Y in co2_s2.columns and pd.notna(co2_s2.at[isin, Y]) if isin in co2_s2.index else False
        if not (has_s1 and has_s2):
            continue
        out.append(isin)

    return out


universe = {}
for Y in range(START_YEAR, END_YEAR + 1):
    universe[Y] = get_universe(Y)

years = list(range(START_YEAR, END_YEAR + 1))
_univ_df = pd.DataFrame({
    "Year": list(universe.keys()),
    "Eligible Firms": [len(v) for v in universe.values()]
})
display(_univ_df.style
        .set_caption("Investment universe — eligible firms per year")
        .hide(axis="index")
        .bar(subset=["Eligible Firms"], color="#4a90d9", vmin=400)
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_7e239 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_7e239_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 34.7%, transparent 34.7%);
# }
# #T_7e239_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 43.6%, transparent 43.6%);
# }
# #T_7e239_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 52.5%, transparent 52.5%);
# }
# #T_7e239_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 55.9%, transparent 55.9%);
# }
# #T_7e239_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 62.4%, transparent 62.4%);
# }
# #T_7e239_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 72.8%, transparent 72.8%);
# }
# #T_7e239_row6_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 86.1%, transparent 86.1%);
# }
# #T_7e239_row7_col1 {
#   width: 10em;
# ...

# %% [markdown]
# ## 7. Covariance Estimation (Sample Matrix, Pairwise-Complete)

# %% [markdown]
# > ### Methodological note — Sample covariance, pairwise-complete, PSD-projected
# >
# > **Estimator (per project §2.1 and Lecture 5 pp. 20–21).** Plain sample covariance with pairwise-complete handling for missing values:
# > own variance on each firm's full available sample; pairwise correlation on the common sample of $i$ and $j$; > $\Sigma_{ij} = \rho_{\text{common}}(i,j)\cdot \sigma_{\text{full}}(i)\cdot \sigma_{\text{full}}(j)$.
# >
# > **Why $\Sigma$ is rank-deficient and not just singular but *indefinite*.** With $N>\tau$ the matrix is singular by construction.
# > Additionally, pairwise-complete estimation combines moments computed on *different* subsamples, which is known (Stambaugh 1997) to produce **non-PSD** matrices —
# > the diagnostic table below shows rank exceeding $\tau=120$ in early years and small negative eigenvalues.
# >
# > **Nearest-PSD projection.** We project $\Sigma$ onto the PSD cone in Frobenius norm (Higham 1988) by clipping negative eigenvalues to zero. This is **distinct from shrinkage**:
# > shrinkage moves *all* eigenvalues toward a target with a tuning parameter $\delta$; the PSD projection only zeros out the negative subspace and leaves positive eigenvalues unchanged — no free parameter.
# > The projection is the minimum modification that makes $w'\Sigma w$ convex, ensuring the long-only QP is well-posed.
# >
# > **Verifications below.** (V1) symmetry; (V2) rank, min eigenvalue raw vs projected, and Frobenius mass of negative eigenvalues per year; (V3) formula identity $\Sigma_{ij}=\rho_{\text{common}}\cdot\sigma_{\text{full}}(i)\sigma_{\text{full}}(j)$ checked on one pair using the *raw* (pre-projection) matrix.

# %%
_cov_cache = {}


def _estimate_cov_raw(isins, win_cols):
    """Raw pairwise-complete sample covariance, BEFORE PSD projection.

    Per Lecture 5 pp. 20–21:
      Var(R_i)   : firm i's full available sample (1/n_i, ML)
      rho(i,j)   : common sample of (i,j) with common-sample means
      Sigma[i,j] = rho(i,j) * sqrt(Var(R_i) * Var(R_j))
    Returns (mu, Sig, count_ij). Sig may be indefinite — this is a known property
    of pairwise-complete (Stambaugh 1997), addressed by the PSD projection
    in estimate_cov() below.
    """
    win_in = [c for c in win_cols if c in ret_m.columns]
    R = ret_m.loc[isins, win_in]
    N = len(isins)

    mu = R.mean(axis=1).values

    R_vals = R.values
    not_nan = ~np.isnan(R_vals)
    mu_full = np.nanmean(R_vals, axis=1)
    R_demeaned = R_vals - mu_full[:, None]
    R_demeaned_zero = np.where(not_nan, R_demeaned, 0.0)
    n_obs = not_nan.sum(axis=1)

    # Own variance: ML estimator (1/n), matches the project's 1/tau formula
    var = np.where(n_obs > 1,
                   np.sum(R_demeaned_zero ** 2, axis=1) / n_obs,
                   0.0)

    # Pairwise-complete cross-moments (common-sample means)
    R_zero = np.where(not_nan, R_vals, 0.0)
    not_nan_f = not_nan.astype(np.float64)

    count_ij = not_nan_f @ not_nan_f.T
    sum_i_ij = R_zero @ not_nan_f.T
    sum_j_ij = not_nan_f @ R_zero.T

    safe_count = np.maximum(count_ij, 1)
    mean_i_ij = sum_i_ij / safe_count
    mean_j_ij = sum_j_ij / safe_count

    cross_ij = R_zero @ R_zero.T
    cov_ij = (cross_ij / safe_count) - mean_i_ij * mean_j_ij

    sum_sq_i_ij = (R_zero ** 2) @ not_nan_f.T
    var_i_ij = np.maximum(sum_sq_i_ij / safe_count - mean_i_ij ** 2, 0)

    sum_sq_j_ij = not_nan_f @ (R_zero ** 2).T
    var_j_ij = np.maximum(sum_sq_j_ij / safe_count - mean_j_ij ** 2, 0)

    denom = np.sqrt(var_i_ij * var_j_ij)
    corr_ij = np.where(denom > 1e-20, cov_ij / denom, 0.0)

    std_own = np.sqrt(var)
    Sig = corr_ij * np.outer(std_own, std_own)
    np.fill_diagonal(Sig, var)
    Sig = (Sig + Sig.T) / 2  # numerical symmetrization only

    return mu, Sig, count_ij


def estimate_cov(isins, win_cols):
    """Sample covariance + nearest-PSD projection (Higham 1988).

    Computes the raw pairwise-complete sample matrix, then projects onto the PSD
    cone in Frobenius norm by clipping negative eigenvalues to 0. Not shrinkage:
    positive eigenvalues are untouched, and there is no tuning parameter.
    """
    mu, Sig_raw, _ = _estimate_cov_raw(isins, win_cols)

    eigvals, eigvecs = np.linalg.eigh(Sig_raw)
    if eigvals[0] < 0:
        eigvals_pos = np.maximum(eigvals, 0.0)
        Sig = (eigvecs * eigvals_pos) @ eigvecs.T
        Sig = (Sig + Sig.T) / 2
    else:
        Sig = Sig_raw

    return mu, Sig


def get_cov(Y):
    if Y not in _cov_cache:
        _cov_cache[Y] = estimate_cov(universe[Y], _estim_window[Y])
    return _cov_cache[Y]


# ─── Verifications ────────────────────────────────────────────────────────────
# (V1) Symmetry of stored Sigma.
# (V2) For each year, report rank, min eigenvalue of raw vs projected matrix,
#      and the Frobenius mass of the negative subspace (info "thrown away").
# (V3) Formula identity Sigma[i,j] = rho_common(i,j) * std_full(i) * std_full(j),
#      checked on the pair with the most common observations, using the RAW matrix.

_diag_rows = []
for Y in range(START_YEAR, END_YEAR + 1):
    # raw matrix for diagnostic
    _, Sig_raw, _ = _estimate_cov_raw(universe[Y], _estim_window[Y])
    _, Sig_used = get_cov(Y)

    N = Sig_raw.shape[0]
    eigs_raw  = np.linalg.eigvalsh(Sig_raw)
    eigs_used = np.linalg.eigvalsh(Sig_used)

    # rank counted against positive eigenvalues only (numerical tol)
    tol = max(1e-12 * eigs_raw[-1], 0.0)
    rank_raw = int((eigs_raw > tol).sum())

    # Frobenius mass of negative eigenvalues (what PSD projection zeroed out)
    neg_mass = float(np.sqrt((eigs_raw[eigs_raw < 0] ** 2).sum()))
    pos_mass = float(np.sqrt((eigs_raw[eigs_raw > 0] ** 2).sum()))

    _diag_rows.append({
        "Year": Y, "N": N,
        "rank(Σ_raw)": rank_raw,
        "min eig raw":  f"{eigs_raw[0]:+.2e}",
        "min eig used": f"{eigs_used[0]:+.2e}",
        "max eig":      f"{eigs_used[-1]:.2e}",
        "‖Σ_neg‖_F / ‖Σ_pos‖_F": f"{neg_mass/pos_mass:.2%}" if pos_mass > 0 else "n/a",
        "sym err": f"{float(np.max(np.abs(Sig_used - Sig_used.T))):.1e}",
    })

_diag_df = pd.DataFrame(_diag_rows)
display(_diag_df.style
        .set_caption("Σ diagnostics — raw matrix is indefinite (pairwise-complete artefact); "
                     "PSD projection brings min eig to ≥ 0. The neg/pos Frobenius ratio "
                     "quantifies how much variance information the projection discards.")
        .hide(axis="index")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))

# (V3) Formula identity on the pair with the most common observations, using RAW Σ.
_Y = START_YEAR
_isins = universe[_Y]
_win = [c for c in _estim_window[_Y] if c in ret_m.columns]
_R = ret_m.loc[_isins, _win]
_R_vals = _R.values
_not_nan = ~np.isnan(_R_vals)
_pair_counts = _not_nan.astype(np.float64) @ _not_nan.astype(np.float64).T
np.fill_diagonal(_pair_counts, 0)
_i, _j = map(int, np.unravel_index(np.argmax(_pair_counts), _pair_counts.shape))

_ri = _R.iloc[_i]; _rj = _R.iloc[_j]
_mask = _ri.notna() & _rj.notna()
_n_common = int(_mask.sum())
_ri_c, _rj_c = _ri[_mask].values, _rj[_mask].values

# Common-sample correlation (matches the code's corr_ij for this pair)
_mi_c, _mj_c = _ri_c.mean(), _rj_c.mean()
_cov_c   = ((_ri_c - _mi_c) * (_rj_c - _mj_c)).sum() / _n_common
_var_i_c = ((_ri_c - _mi_c) ** 2).sum() / _n_common
_var_j_c = ((_rj_c - _mj_c) ** 2).sum() / _n_common
_corr_c  = _cov_c / np.sqrt(_var_i_c * _var_j_c)

# Full-sample own stds (matches std_own in code)
_ri_f, _rj_f = _ri.dropna().values, _rj.dropna().values
_std_i_full = np.sqrt(((_ri_f - _ri_f.mean()) ** 2).sum() / len(_ri_f))
_std_j_full = np.sqrt(((_rj_f - _rj_f.mean()) ** 2).sum() / len(_rj_f))

_sig_ij_manual = _corr_c * _std_i_full * _std_j_full
_, _Sig_raw_2013, _ = _estimate_cov_raw(_isins, _win)
_sig_ij_code = float(_Sig_raw_2013[_i, _j])

print(f"V3 formula identity (Y={_Y}, pair {_i}-{_j}, common n={_n_common}):")
print(f"   rho_common × std_full(i) × std_full(j) = {_sig_ij_manual:+.6e}")
print(f"   Σ_raw[i,j]                              = {_sig_ij_code:+.6e}")
print(f"   match = {np.isclose(_sig_ij_manual, _sig_ij_code, rtol=1e-10, atol=1e-14)}")
# Out:
# <style type="text/css">
# #T_9beb2 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_9beb2">
#   <caption>Σ diagnostics — raw matrix is indefinite (pairwise-complete artefact); PSD projection brings min eig to ≥ 0. The neg/pos Frobenius ratio quantifies how much variance information the projection discards.</caption>
#   <thead>
#     <tr>
#       <th id="T_9beb2_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_9beb2_level0_col1" class="col_heading level0 col1" >N</th>
#       <th id="T_9beb2_level0_col2" class="col_heading level0 col2" >rank(Σ_raw)</th>
#       <th id="T_9beb2_level0_col3" class="col_heading level0 col3" >min eig raw</th>
#       <th id="T_9beb2_level0_col4" class="col_heading level0 col4" >min eig used</th>
#       <th id="T_9beb2_level0_col5" class="col_heading level0 col5" >max eig</th>
#       <th id="T_9beb2_level0_col6" class="col_heading level0 col6" >‖Σ_neg‖_F / ‖Σ_pos‖_F</th>
# ...

# %% [markdown]
# ## 8. Utility Functions

# %%
def fill_oos_returns(eligible, next_months):
    """Fill missing OOS returns with delisting detection."""
    R_oos = ret_m.loc[eligible].reindex(columns=next_months).copy()

    for isin in eligible:
        delisted = False
        for k, t in enumerate(next_months):
            if delisted:
                R_oos.at[isin, t] = np.nan
                continue
            if pd.isna(R_oos.at[isin, t]):
                t_idx = _monthly_idx.get(t, None)
                prev_t = monthly_all[t_idx - 1] if t_idx and t_idx > 0 else None
                had_price_prev = (prev_t is not None
                                  and prev_t in ri_m.columns
                                  and isin in ri_m.index
                                  and pd.notna(ri_m.at[isin, prev_t]))
                if had_price_prev:
                    R_oos.at[isin, t] = -1.0
                    delisted = True
                else:
                    R_oos.at[isin, t] = 0.0

    return R_oos.fillna(0.0)


_oos_cache = {}


def get_oos_returns(Y):
    if Y not in _oos_cache:
        _oos_cache[Y] = fill_oos_returns(universe[Y], _months_of[Y + 1])
    return _oos_cache[Y]


_vww_cache = {}


def vw_weights(Y):
    """Value-weighted benchmark weights using annual market caps."""
    if Y not in _vww_cache:
        isins = universe[Y]
        cap = mv_y.loc[isins, Y].fillna(0.0)
        s = cap.sum()
        _vww_cache[Y] = (cap / s if s > 0
                         else pd.Series(np.ones(len(isins)) / len(isins), index=isins))
    return _vww_cache[Y]

# %% [markdown]
# ## 9. Min-Variance Optimisation (Part I)

# %%
_drifted_w = {}


def min_var_weights(Sigma, isins, Y):
    N = Sigma.shape[0]
    if Y in _drifted_w:
        prev = _drifted_w[Y]
        w0 = np.array([prev.get(i, 0.0) for i in isins])
        w0 = w0 / w0.sum() if w0.sum() > 0 else np.ones(N) / N
    else:
        w0 = np.ones(N) / N

    res = minimize(
        fun=lambda w: float(w @ Sigma @ w),
        x0=w0,
        jac=lambda w: 2.0 * (Sigma @ w),
        method="SLSQP",
        bounds=[(0.0, None)] * N,
        constraints={"type": "eq", "fun": lambda w: w.sum() - 1.0},
        options={"ftol": 1e-10, "maxiter": 1000},
    )
    if not res.success:
        print(f"   WARNING: optimizer did not converge for Y={Y}: {res.message}")
    return res.x


mv_w_dict = {}
mv_ret = {}

for Y in range(START_YEAR, END_YEAR + 1):
    eligible = universe[Y]
    N = len(eligible)
    if N == 0:
        print(f"   Y={Y}: 0 firms → skip")
        continue

    _, Sig = get_cov(Y)
    w = min_var_weights(Sig, eligible, Y)
    mv_w_dict[Y] = pd.Series(w, index=eligible)

    ea_vol = np.sqrt(float(w @ Sig @ w) * 12) * 100

    next_months = _months_of[Y + 1]
    R_next = get_oos_returns(Y)
    ww = w.copy()
    port_ret = []
    for t in next_months:
        r_t = R_next[t].values
        rp_t = float(ww @ r_t)
        port_ret.append(rp_t)
        ww = ww * (1.0 + r_t) / max(1.0 + rp_t, 1e-12)
    mv_ret[Y + 1] = pd.Series(port_ret, index=next_months)
    _drifted_w[Y + 1] = dict(zip(eligible, ww))

    n_nonzero = (w > 1e-6).sum()
f"ex-ante ann.σ: {ea_vol:.2f}%"

rp_mv = pd.concat(mv_ret).droplevel(0).sort_index()
rp_mv.index = pd.DatetimeIndex(rp_mv.index)

_mv_summary = pd.DataFrame([{
    "Year": Y,
    "Firms": len(universe[Y]),
    "Non-zero wgts": int((mv_w_dict[Y] > 1e-6).sum()),
    "Ex-ante ann. σ (%)": round(np.sqrt(float(mv_w_dict[Y].values @ get_cov(Y)[1] @ mv_w_dict[Y].values)*12)*100, 2)
} for Y in years])
display(_mv_summary.style
        .set_caption("Min-variance opt — rolling summary")
        .hide(axis="index")
        .format({"Ex-ante ann. σ (%)": "{:.2f}"})
        .bar(subset=["Non-zero wgts"], color="#4a90d9", vmin=0)
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_19ccb caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_19ccb_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 75.0%, transparent 75.0%);
# }
# #T_19ccb_row1_col2, #T_19ccb_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 62.5%, transparent 62.5%);
# }
# #T_19ccb_row2_col2, #T_19ccb_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 65.6%, transparent 65.6%);
# }
# #T_19ccb_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 87.5%, transparent 87.5%);
# }
# #T_19ccb_row6_col2, #T_19ccb_row11_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 78.1%, transparent 78.1%);
# }
# #T_19ccb_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 96.9%, transparent 96.9%);
# }
# #T_19ccb_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 100.0%, transparent 100.0%);
# }
# ...

# %% [markdown]
# ## 10. Value-Weighted Benchmark (Monthly Rebalancing)

# %%
vw_ret = {}
for Y in range(START_YEAR, END_YEAR + 1):
    eligible = universe[Y]
    next_months = _months_of[Y + 1]
    R_oos_vw = get_oos_returns(Y)
    port = []

    for t in next_months:
        idx = _monthly_idx.get(t)
        if idx is None or idx == 0:
            port.append(np.nan)
            continue
        prev_t = monthly_all[idx - 1]
        cap = (mv_m.loc[eligible, prev_t].fillna(0)
               if prev_t in mv_m.columns else pd.Series(0.0, index=eligible))
        tot = cap.sum()
        if tot <= 0:
            port.append(0.0)
            continue
        r_t = R_oos_vw[t].values if t in R_oos_vw.columns else np.zeros(len(eligible))
        port.append(float((cap / tot).values @ r_t))

    vw_ret[Y + 1] = pd.Series(port, index=next_months)

rp_vw = pd.concat(vw_ret).droplevel(0).sort_index()
rp_vw.index = pd.DatetimeIndex(rp_vw.index)

# %% [markdown]
# ## 11. Performance Statistics

# %% [markdown]
# > ### Interrogation A — MV severely underperforms VW; explain it, don't hide it
# >
# > Expected output: Sharpe 0.22 (MV) vs 0.41 (VW); arithmetic return 4.67% vs 8.19% — a **3.5 pp/yr drag**.
# > Volatility reduction is real but small: 13.4% vs 15.9% (only 2.5 pp).
# >
# > **Why this happens (use these in your interpretation):**
# > 1. **Regime.** 2014–2025 was a strong large-cap rally in Europe; long-only MV concentrates in defensive small/mid-caps that lag in such regimes.
# > 2. **Survivorship/delisting drag.** Several MV holdings (Dignity, De La Rue, Dechra) later delisted. Our `-100%` delisting rule is correct (no look-ahead) but adds realized losses.
# > 3. **Concentration cost.** With ~22–30 active names out of 500+, idiosyncratic shocks dominate.
# > 4. **Theoretical reason.** Lecture 5 p. 23 makes exactly this point: long-only constraints discard most of the universe and load on a few low-vol names.
# >
# > **For the report:** present this as a *known property* of constrained GMV out-of-sample, not a surprise. Suggest improvements (weight cap, sector neutrality) explicitly.

# %%
def compute_perf(rp, rf_s, label):
    rp = rp.dropna()
    rf = rf_s.reindex(rp.index).ffill().fillna(0)
    T = len(rp)
    mu_arith = 12 * rp.mean()
    mu_geom = (1 + rp).prod() ** (12 / T) - 1
    sig_ann = rp.std() * np.sqrt(12)
    rf_ann = 12 * rf.mean()
    SR = (mu_arith - rf_ann) / sig_ann
    cum = (1 + rp).cumprod()
    mdd = ((cum - cum.cummax()) / cum.cummax()).min()
    return {
        "Portfolio": label,
        "Ann. Return Arith. (%)": round(mu_arith * 100, 2),
        "Ann. Return Geom. (%)": round(mu_geom * 100, 2),
        "Ann. Vol (%)": round(sig_ann * 100, 2),
        "Sharpe": round(SR, 3),
        "Min Mo. (%)": round(rp.min() * 100, 2),
        "Max Mo. (%)": round(rp.max() * 100, 2),
        "Max DD (%)": round(mdd * 100, 2),
    }


stats_df = pd.DataFrame([
    compute_perf(rp_vw, rf_mon, "Val-Wgt P^(vw)"),
    compute_perf(rp_mv, rf_mon, "Min-Var P_oos^(mv)"),
]).set_index("Portfolio")


display(stats_df.style
        .set_caption("Part I — Performance: Val-Wgt vs Min-Var")
        .format({"Ann. Return Arith. (%)": "{:.2f}", "Ann. Return Geom. (%)": "{:.2f}",
                 "Ann. Vol (%)": "{:.2f}", "Sharpe": "{:.3f}",
                 "Min Mo. (%)": "{:.2f}", "Max Mo. (%)": "{:.2f}", "Max DD (%)": "{:.2f}"})
        .highlight_min(subset=["Ann. Vol (%)","Max DD (%)"], color="#c6efce")
        .highlight_max(subset=["Sharpe","Ann. Return Arith. (%)"], color="#ffeb9c")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_32f34 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_32f34_row0_col0, #T_32f34_row0_col3 {
#   background-color: #ffeb9c;
# }
# #T_32f34_row0_col6, #T_32f34_row1_col2 {
#   background-color: #c6efce;
# }
# </style>
# <table id="T_32f34">
#   <caption>Part I — Performance: Val-Wgt vs Min-Var</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32f34_level0_col0" class="col_heading level0 col0" >Ann. Return Arith. (%)</th>
#       <th id="T_32f34_level0_col1" class="col_heading level0 col1" >Ann. Return Geom. (%)</th>
#       <th id="T_32f34_level0_col2" class="col_heading level0 col2" >Ann. Vol (%)</th>
#       <th id="T_32f34_level0_col3" class="col_heading level0 col3" >Sharpe</th>
#       <th id="T_32f34_level0_col4" class="col_heading level0 col4" >Min Mo. (%)</th>
#       <th id="T_32f34_level0_col5" class="col_heading level0 col5" >Max Mo. (%)</th>
# ...

# %% [markdown]
# ## 12. Verification Checks

# %%
for Y, w in mv_w_dict.items():
    assert abs(w.sum() - 1.0) < 1e-6, f"Y={Y}: weights sum to {w.sum()}"

for Y, w in mv_w_dict.items():
    assert (w >= -1e-8).all(), f"Y={Y}: negative weights found"

expected_months = sum(len(_months_of[Y + 1]) for Y in range(START_YEAR, END_YEAR + 1))
actual_mv = len(rp_mv.dropna())
actual_vw = len(rp_vw.dropna())

assert rp_mv.isna().sum() == 0, "NaN in min-var returns"
assert rp_vw.isna().sum() == 0, "NaN in VW returns"

display(HTML(
    '<div style="font-family:monospace;background:#f0f8f0;padding:10px 16px;'
    'border-left:4px solid #2e7d32;border-radius:4px">'
    f'<b>Verification</b><br>'
    f'✓ All weight vectors sum to 1<br>'
    f'✓ All weights non-negative<br>'
    f'✓ Min-Var: {actual_mv} months &nbsp;|&nbsp; Val-Wgt: {actual_vw} months<br>'
    f'✓ No NaN in return series'
    '</div>'
))
# Out:
# <div style="font-family:monospace;background:#f0f8f0;padding:10px 16px;border-left:4px solid #2e7d32;border-radius:4px"><b>Verification</b><br>✓ All weight vectors sum to 1<br>✓ All weights non-negative<br>✓ Min-Var: 144 months &nbsp;|&nbsp; Val-Wgt: 144 months<br>✓ No NaN in return series</div>

# %% [markdown]
# ## 13. Top Holdings

# %% [markdown]
# > ### Interrogation B + E — Concentration risk and delisted holdings
# >
# > Looking at the snapshots below, two issues to flag in the report:
# >
# > **B. Concentration is alarming.**
# > - 23/470 active holdings in 2013 (≈ 5% of universe); 22/565 in 2024.
# > - Top-3 weight in 2013: Teva 15% + Valiant 12% + Swisscom 11% ≈ **38% in 3 names**.
# > - This is the textbook outcome of long-only GMV without weight caps.
# >
# > **E. The portfolio held firms that subsequently delisted.**
# > - Dignity (delisted 25/05/23), De La Rue (03/07/25), Dechra (17/01/24) appear in early-period holdings.
# > - **This is correct behavior** — selection used only information available at decision time, no look-ahead.
# > - But these positions contributed real losses to the realized OOS return.
# >
# > **Robustness checks worth running and discussing:**
# > - Re-run MV with $\alpha_i \le 5\%$ weight cap.
# > - Report turnover and the share of delisting-related losses in total OOS drag.

# %%
# Top 10 Min-Var holdings — snapshot years
for Y in [2013, 2018, 2024]:
    if Y not in mv_w_dict:
        continue
    w = mv_w_dict[Y].sort_values(ascending=False)
    n_nz = int((w > 1e-6).sum())
    rows = []
    for rk, (isin, wt) in enumerate(w.head(10).items(), 1):
        cty = static.loc[static["ISIN"] == isin, "Country"].values
        rows.append({"Rank": rk,
                     "Name": isin_name.get(isin, isin),
                     "Country": cty[0] if len(cty) else "",
                     "Weight (%)": round(wt * 100, 2)})
    _df = pd.DataFrame(rows)
    display(_df.style
              .set_caption(f"Dec {Y} — Top 10 Min-Var holdings  ({n_nz}/{len(w)} non-zero)")
              .hide(axis="index")
              .format({"Weight (%)": "{:.2f}"})
              .bar(subset=["Weight (%)"], color="#4a90d9", vmin=0)
              .set_table_styles([{"selector":"caption","props":
                  [("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_bc316 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_bc316_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 100.0%, transparent 100.0%);
# }
# #T_bc316_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 84.1%, transparent 84.1%);
# }
# #T_bc316_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 69.6%, transparent 69.6%);
# }
# #T_bc316_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 58.1%, transparent 58.1%);
# }
# #T_bc316_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 49.9%, transparent 49.9%);
# }
# #T_bc316_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 47.9%, transparent 47.9%);
# }
# #T_bc316_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #4a90d9 47.4%, transparent 47.4%);
# }
# #T_bc316_row7_col3 {
#   width: 10em;
# ...

# %% [markdown]
# ## 14. Figures

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
fig.suptitle("SAAM Part I — EUR: Min-Var vs Value-Weighted (2014–2025)",
             fontsize=13, fontweight="bold")
C1, C2 = "steelblue", "darkorange"
fmt = mdates.DateFormatter("%Y")
loc = mdates.YearLocator(2)

ax = axes[0, 0]
cm = (1 + rp_mv.dropna()).cumprod()
cv = (1 + rp_vw.dropna()).cumprod()
ax.plot(cm.index, cm.values, color=C1, lw=1.8, label=r"Min-Var $P_{oos}^{(mv)}$")
ax.plot(cv.index, cv.values, color=C2, lw=1.8, ls="--", label=r"Val-Wgt $P^{(vw)}$")
ax.set_title("Cumulative Return (base=1, Jan 2014)")
ax.set_ylabel("Cumulative return")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[0, 1]
rv_mv = rp_mv.rolling(12).std() * np.sqrt(12) * 100
rv_vw = rp_vw.rolling(12).std() * np.sqrt(12) * 100
ax.plot(rp_mv.index, rv_mv.values, color=C1, lw=1.6, label="Min-Var")
ax.plot(rp_vw.index, rv_vw.values, color=C2, lw=1.6, ls="--", label="Val-Wgt")
ax.set_title("Rolling 12m Annualised Volatility (%)")
ax.set_ylabel("Vol (%)")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[1, 0]


def drawdown_series(rp):
    c = (1 + rp.dropna()).cumprod()
    return (c - c.cummax()) / c.cummax() * 100


dd_mv = drawdown_series(rp_mv)
dd_vw = drawdown_series(rp_vw)
ax.fill_between(dd_mv.index, dd_mv.values, 0, alpha=0.45, color=C1, label="Min-Var")
ax.fill_between(dd_vw.index, dd_vw.values, 0, alpha=0.30, color=C2, label="Val-Wgt")
ax.set_title("Drawdown from Peak (%)")
ax.set_ylabel("Drawdown (%)")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[1, 1]
yrs = sorted(universe.keys())
ax.bar(yrs, [len(universe[y]) for y in yrs], color=C1, alpha=0.8,
       edgecolor="white", width=0.6)
ax.set_title("EUR Investment Set Size by Year")
ax.set_ylabel("Eligible firms")
ax.set_xticks(yrs)
ax.set_xticklabels(yrs, rotation=45)
ax.grid(axis="y", alpha=0.3)
for y in yrs:
    ax.text(y, len(universe[y]) + 5, str(len(universe[y])), ha="center", fontsize=8)

    plt.tight_layout()
    plt.tight_layout()
    plt.savefig(f"{OUT}SAAM_Part1_EUR_figures.pdf", dpi=150, bbox_inches="tight")
    plt.show()

# %% [markdown]
# # PART II — Carbon-Aware Portfolio Allocation

# %% [markdown]
# ## 15. Carbon Data Preparation

# %%
co2_tot = co2_s1 + co2_s2
rev_m = rev / 1000.0  # thousands → millions USD

with np.errstate(divide="ignore", invalid="ignore"):
    CI_firm = co2_tot / rev_m

# %% [markdown]
# ## 16. Carbon Metrics — Baseline Portfolios

# %% [markdown]
# > ### Interrogation D — VW carbon coverage is 0.99, not 1.00
# >
# > The output table will show `cov_W ≈ 0.99` for the VW portfolio's WACI.
# >
# > **Cause:** a small number of EUR firms have CO₂ emissions reported but **missing revenue** → CI = NaN → those firms are excluded from the WACI numerator while still receiving market-cap weight in the denominator.
# >
# > **Effect:** small downward bias (~1%) in reported WACI for VW. Does not affect CF (which uses Cap, not Revenue).
# >
# > **For the report:** mention this in the "data quality" limitations bullet.

# %%
def carbon_metrics(weights, Y):
    """WACI (tCO2/M$rev) and CF (tCO2/M$inv) for a portfolio at year-end Y."""
    isins = list(weights.index)
    w = weights.values.astype(float)
    E = co2_tot.loc[isins, Y].values.astype(float)
    R = rev_m.loc[isins, Y].values.astype(float)
    C = mv_y.loc[isins, Y].values.astype(float)

    with np.errstate(divide="ignore", invalid="ignore"):
        CI = np.where((R > 0) & np.isfinite(R), E / R, np.nan)
    valid_W = np.isfinite(CI)
    WACI = float(np.nansum(w * np.where(valid_W, CI, 0.0)))
    cov_W = float(w[valid_W].sum())

    with np.errstate(divide="ignore", invalid="ignore"):
        ED = np.where((C > 0) & np.isfinite(C), E / C, np.nan)
    valid_F = np.isfinite(ED)
    CF = float(np.nansum(w * np.where(valid_F, ED, 0.0)))
    cov_F = float(w[valid_F].sum())

    return {"WACI": WACI, "CF": CF, "cov_W": cov_W, "cov_F": cov_F}


mv_carbon_rows, vw_carbon_rows = [], []
for Y in years:
    mv_carbon_rows.append({"Y": Y, **carbon_metrics(mv_w_dict[Y], Y)})
    vw_carbon_rows.append({"Y": Y, **carbon_metrics(vw_weights(Y), Y)})

mv_carbon = pd.DataFrame(mv_carbon_rows).set_index("Y")
vw_carbon = pd.DataFrame(vw_carbon_rows).set_index("Y")

_cm = mv_carbon[["WACI","CF"]].rename(columns={
    "WACI": "WACI (tCO₂/M$rev)", "CF": "CF (tCO₂/M$inv)"})
_cv = vw_carbon[["WACI","CF"]].rename(columns={
    "WACI": "WACI (tCO₂/M$rev)", "CF": "CF (tCO₂/M$inv)"})
display(_cm.style
        .set_caption("Min-Variance P^(mv)_oos — Carbon Metrics by Year")
        .format("{:.2f}")
        .background_gradient(cmap="YlOrRd")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
display(_cv.style
        .set_caption("Value-Weighted P^(vw) — Carbon Metrics by Year")
        .format("{:.2f}")
        .background_gradient(cmap="YlOrRd")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_f1011 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_f1011_row0_col0, #T_f1011_row11_col1 {
#   background-color: #fff4b2;
#   color: #000000;
# }
# #T_f1011_row0_col1, #T_f1011_row11_col0 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_f1011_row1_col0 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_f1011_row1_col1, #T_f1011_row4_col0 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_f1011_row2_col0 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_f1011_row2_col1 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_f1011_row3_col0 {
#   background-color: #fead4a;
#   color: #000000;
# }
# #T_f1011_row3_col1 {
#   background-color: #9f0026;
#   color: #f1f1f1;
# }
# #T_f1011_row4_col1 {
#   background-color: #fd8239;
#   color: #f1f1f1;
# }
# #T_f1011_row5_col0 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_f1011_row5_col1 {
#   background-color: #fed06c;
# ...

# %% [markdown]
# ## 18. Top Carbon Contributors

# %%
# Top 10 carbon-intensive firms — snapshot years
def top_n_by_CI(Y, n=10):
    isins = universe[Y]
    CI = (co2_tot.loc[isins, Y] / rev_m.loc[isins, Y]).dropna().sort_values(ascending=False)
    rows = []
    for rk, isin in enumerate(CI.head(n).index, 1):
        cty = static.loc[static["ISIN"] == isin, "Country"].values
        rows.append({"Rank": rk,
                     "Name": isin_name.get(isin, isin),
                     "Country": cty[0] if len(cty) else "",
                     "CI (tCO₂/M$rev)": round(float(CI.loc[isin]), 1),
                     "VW weight (%)": round(float(vw_weights(Y).get(isin, 0)) * 100, 3)})
    return pd.DataFrame(rows)

snapshot_years = [2013, 2018, 2024]

for Y in snapshot_years:
    _df = top_n_by_CI(Y)
    display(_df.style
              .set_caption(f"Top 10 Carbon-Intensive Firms in EUR Universe — {Y}")
              .hide(axis="index")
              .format({"CI (tCO₂/M$rev)": "{:,.1f}", "VW weight (%)": "{:.3f}"})
              .bar(subset=["CI (tCO₂/M$rev)"], color="#e05c2d", vmin=0)
              .set_table_styles([{"selector":"caption","props":
                  [("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_64394 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_64394_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #e05c2d 100.0%, transparent 100.0%);
# }
# #T_64394_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #e05c2d 77.1%, transparent 77.1%);
# }
# #T_64394_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #e05c2d 58.2%, transparent 58.2%);
# }
# #T_64394_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #e05c2d 41.9%, transparent 41.9%);
# }
# #T_64394_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #e05c2d 33.9%, transparent 33.9%);
# }
# #T_64394_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #e05c2d 32.7%, transparent 32.7%);
# }
# #T_64394_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #e05c2d 23.6%, transparent 23.6%);
# }
# #T_64394_row7_col3 {
#   width: 10em;
# ...

# %% [markdown]
# ## 19. Plot — Carbon Metrics Time Series

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4.5))
C1, C2 = "steelblue", "darkorange"

ax = axes[0]
ax.plot(mv_carbon.index, mv_carbon["WACI"], "o-", color=C1, lw=1.8,
        label=r"Min-Var $P^{(mv)}_{oos}$")
ax.plot(vw_carbon.index, vw_carbon["WACI"], "s--", color=C2, lw=1.8,
        label=r"Val-Wgt $P^{(vw)}$")
ax.set_title("WACI — Weighted-Average Carbon Intensity")
ax.set_xlabel("Year")
ax.set_ylabel(r"tCO$_2$ / M\$ revenue")
ax.grid(alpha=0.3)
ax.legend(fontsize=9)

ax = axes[1]
ax.plot(mv_carbon.index, mv_carbon["CF"], "o-", color=C1, lw=1.8,
        label=r"Min-Var $P^{(mv)}_{oos}$")
ax.plot(vw_carbon.index, vw_carbon["CF"], "s--", color=C2, lw=1.8,
        label=r"Val-Wgt $P^{(vw)}$")
ax.set_title("CF — Carbon Footprint (ownership-attributed)")
ax.set_xlabel("Year")
ax.set_ylabel(r"tCO$_2$ / M\$ invested")
ax.grid(alpha=0.3)
ax.legend(fontsize=9)

plt.tight_layout()
plt.tight_layout()
plt.savefig(f"{OUT}SAAM_Part2_carbon_baseline.pdf", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Section 3.2 — Active Investor: MV with CF ≤ 0.5 × CF(MV)

# %% [markdown]
# ## 19. CF Targets and Feasibility

# %%
cf_target_mv = (mv_carbon["CF"] * 0.5).rename("target_CF").copy()


def cf_vector(isins, Y):
    """c_i = E_i,Y / Cap_i,Y (inf where cap missing — forces alpha_i = 0)."""
    E = co2_tot.loc[isins, Y].values.astype(float)
    C = mv_y.loc[isins, Y].values.astype(float)
    with np.errstate(divide="ignore", invalid="ignore"):
        c = np.where((C > 0) & np.isfinite(C) & np.isfinite(E), E / C, np.inf)
    return c, np.isfinite(c)


_mfcf_cache = {}


def get_min_cf(Y):
    """Minimum achievable CF for the year-Y universe (LP)."""
    if Y not in _mfcf_cache:
        isins = universe[Y]
        c, valid = cf_vector(isins, Y)
        N = len(isins)
        if not valid.any():
            _mfcf_cache[Y] = np.nan
        else:
            c_lp = np.where(valid, c, 1e20)
            res = linprog(c=c_lp, A_eq=np.ones((1, N)), b_eq=[1.0],
                          bounds=[(0.0, 1.0)] * N, method="highs")
            _mfcf_cache[Y] = float(c_lp @ res.x) if res.success else np.nan
    return _mfcf_cache[Y]


adj_targets = {}
relax_log_mv05 = []
for Y in years:
    cf_min = get_min_cf(Y)
    target_raw = float(cf_target_mv.loc[Y])
    if cf_min > target_raw:
        adj_targets[Y] = cf_min * 1.001
        relax_log_mv05.append({"Y": Y, "raw_target": target_raw,
                                "cf_min_universe": cf_min,
                                "effective_target": adj_targets[Y],
                                "status": "RELAXED"})
    else:
        adj_targets[Y] = target_raw
        relax_log_mv05.append({"Y": Y, "raw_target": target_raw,
                                "cf_min_universe": cf_min,
                                "effective_target": adj_targets[Y],
                                "status": "feasible"})

_relax_df = pd.DataFrame(relax_log_mv05).set_index("Y")
n_relaxed = int((_relax_df["status"] == "RELAXED").sum())
display(_relax_df.style
        .set_caption(f"MV(0.5) — Target feasibility: {n_relaxed}/{len(years)} years required relaxation. "
                     f"Where status=RELAXED, the realized CF is the universe-floor, NOT a true 50% reduction.")
        .format({"raw_target": "{:.3f}", "cf_min_universe": "{:.3f}",
                 "effective_target": "{:.3f}"})
        .map(lambda v: "background-color:#ffd5d5" if v == "RELAXED" else "",
             subset=["status"])
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_dcdb9 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_dcdb9">
#   <caption>MV(0.5) — Target feasibility: 0/12 years required relaxation. Where status=RELAXED, the realized CF is the universe-floor, NOT a true 50% reduction.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcdb9_level0_col0" class="col_heading level0 col0" >raw_target</th>
#       <th id="T_dcdb9_level0_col1" class="col_heading level0 col1" >cf_min_universe</th>
#       <th id="T_dcdb9_level0_col2" class="col_heading level0 col2" >effective_target</th>
#       <th id="T_dcdb9_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Y</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# ## 20. Constrained Min-Variance Optimizer

# %%
def min_var_cf_constrained(Sigma, c, target, isins, Y, prev_drift=None):
    N = Sigma.shape[0]
    valid = np.isfinite(c)
    invalid = ~valid

    if prev_drift is not None:
        w0 = np.array([prev_drift.get(i, 0.0) for i in isins])
        w0[invalid] = 0.0
        s = w0.sum()
        w0 = w0 / s if s > 0 else np.where(valid, 1.0, 0.0) / max(valid.sum(), 1)
    else:
        w0 = np.where(valid, 1.0, 0.0) / max(valid.sum(), 1)

    bounds = [(0.0, 0.0) if invalid[i] else (0.0, 1.0) for i in range(N)]
    c_safe = np.where(valid, c, 0.0)
    constraints = [
        {"type": "eq", "fun": lambda w: w.sum() - 1.0, "jac": lambda w: np.ones(N)},
        {"type": "ineq", "fun": lambda w: target - c_safe @ w, "jac": lambda w: -c_safe},
    ]
    return minimize(
        fun=lambda w: float(w @ Sigma @ w),
        x0=w0, jac=lambda w: 2.0 * (Sigma @ w),
        method="SLSQP", bounds=bounds, constraints=constraints,
        options={"ftol": 1e-10, "maxiter": 2000},
    )

# %% [markdown]
# ## 21. Rolling Loop — P^(mv)_oos(0.5)

# %%
mv05_w_dict = {}
mv05_ret = {}
_mv05_drift = {}
_mv05_diag = []  # convergence + post-clip CF violation

for Y in years:
    eligible = universe[Y]
    target = adj_targets[Y]
    _, Sig = get_cov(Y)
    c, valid = cf_vector(eligible, Y)

    res = min_var_cf_constrained(Sig, c, target, eligible, Y,
                                  prev_drift=_mv05_drift.get(Y))

    # CF of the raw SLSQP result (before any clip/renorm)
    w_raw = np.asarray(res.x, dtype=float)
    cf_raw  = float(np.where(valid, c, 0.0) @ w_raw)
    sum_raw = float(w_raw.sum())

    w = np.clip(w_raw, 0.0, 1.0)
    if w.sum() > 0:
        w /= w.sum()

    # CF after clip+renorm
    cf_renorm = float(np.where(valid, c, 0.0) @ w)

    _mv05_diag.append({
        "Y": Y, "converged": bool(res.success),
        "iter": int(getattr(res, "nit", -1)),
        "sum(w_raw)-1": sum_raw - 1.0,
        "CF_raw": cf_raw, "CF_renorm": cf_renorm,
        "target": target,
        "CF_violation_renorm": max(cf_renorm - target, 0.0),
    })

    mv05_w_dict[Y] = pd.Series(w, index=eligible)

    R_next = get_oos_returns(Y)
    next_months = _months_of[Y + 1]
    ww = w.copy()
    port_ret = []
    for t in next_months:
        r_t = R_next[t].values
        rp_t = float(ww @ r_t)
        port_ret.append(rp_t)
        ww = ww * (1.0 + r_t) / max(1.0 + rp_t, 1e-12)
    mv05_ret[Y + 1] = pd.Series(port_ret, index=next_months)
    _mv05_drift[Y + 1] = dict(zip(eligible, ww))

rp_mv05 = pd.concat(mv05_ret).droplevel(0).sort_index()
rp_mv05.index = pd.DatetimeIndex(rp_mv05.index)

# Diagnostics
_diag_mv05 = pd.DataFrame(_mv05_diag).set_index("Y")
n_fail = int((~_diag_mv05["converged"]).sum())
max_viol = float(_diag_mv05["CF_violation_renorm"].max())
print(f"MV(0.5) — SLSQP failures: {n_fail}/{len(years)} | "
      f"max post-renorm CF violation: {max_viol:.4g} (target ~{adj_targets[2013]:.2f})")
display(_diag_mv05.style
        .set_caption("MV(0.5) — Per-year optimizer diagnostics (converged + post-renorm slack)")
        .format({"sum(w_raw)-1": "{:+.2e}",
                 "CF_raw": "{:.3f}", "CF_renorm": "{:.3f}", "target": "{:.3f}",
                 "CF_violation_renorm": "{:.2e}"})
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# MV(0.5) — SLSQP failures: 0/12 | max post-renorm CF violation: 6.821e-13 (target ~12.73)
# <style type="text/css">
# #T_3134f caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_3134f">
#   <caption>MV(0.5) — Per-year optimizer diagnostics (converged + post-renorm slack)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3134f_level0_col0" class="col_heading level0 col0" >converged</th>
#       <th id="T_3134f_level0_col1" class="col_heading level0 col1" >iter</th>
#       <th id="T_3134f_level0_col2" class="col_heading level0 col2" >sum(w_raw)-1</th>
#       <th id="T_3134f_level0_col3" class="col_heading level0 col3" >CF_raw</th>
#       <th id="T_3134f_level0_col4" class="col_heading level0 col4" >CF_renorm</th>
#       <th id="T_3134f_level0_col5" class="col_heading level0 col5" >target</th>
#       <th id="T_3134f_level0_col6" class="col_heading level0 col6" >CF_violation_renorm</th>
#     </tr>
# ...

# %% [markdown]
# ## 22. Verification — MV05

# %%
mv05_carbon = pd.DataFrame(
    [{"Y": Y, **carbon_metrics(mv05_w_dict[Y], Y)} for Y in years]
).set_index("Y")

cf_check = pd.DataFrame({
    "raw_target_0.5xMV": cf_target_mv,
    "target_eff": pd.Series(adj_targets),
    "CF_realized": mv05_carbon["CF"],
})
cf_check["slack_vs_eff"]    = cf_check["target_eff"] - cf_check["CF_realized"]
cf_check["pct_of_MV_base"]  = (cf_check["CF_realized"] / mv_carbon["CF"]) * 100
cf_check["status"] = np.where(
    cf_check["raw_target_0.5xMV"] < cf_check["target_eff"] - 1e-9, "RELAXED", "OK")

def _slack_color(v):
    try:
        return "background-color:#c6efce" if abs(float(v)) < 0.01 else "background-color:#fff2cc"
    except (TypeError, ValueError):
        return ""

display(cf_check.style
        .set_caption("MV(0.5) — CF realized vs original (0.5xMV) target. "
                     "pct_of_MV_base shows the actual reduction achieved; "
                     "RELAXED years are pinned at the universe floor, not at 50%.")
        .format({"raw_target_0.5xMV": "{:.3f}",
                 "target_eff": "{:.3f}",
                 "CF_realized": "{:.3f}",
                 "slack_vs_eff": "{:+.3f}",
                 "pct_of_MV_base": "{:.1f}%"})
        .map(_slack_color, subset=["slack_vs_eff"])
        .map(lambda v: "background-color:#ffd5d5" if v == "RELAXED" else "",
             subset=["status"])
        .set_table_styles([{"selector": "caption",
                            "props": [("font-weight", "bold"), ("font-size", "13px")]}]))
# Out:
# <style type="text/css">
# #T_a63df caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_a63df_row0_col3, #T_a63df_row1_col3, #T_a63df_row2_col3, #T_a63df_row3_col3, #T_a63df_row4_col3, #T_a63df_row5_col3, #T_a63df_row6_col3, #T_a63df_row7_col3, #T_a63df_row8_col3, #T_a63df_row9_col3, #T_a63df_row10_col3, #T_a63df_row11_col3 {
#   background-color: #c6efce;
# }
# </style>
# <table id="T_a63df">
#   <caption>MV(0.5) — CF realized vs original (0.5xMV) target. pct_of_MV_base shows the actual reduction achieved; RELAXED years are pinned at the universe floor, not at 50%.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a63df_level0_col0" class="col_heading level0 col0" >raw_target_0.5xMV</th>
#       <th id="T_a63df_level0_col1" class="col_heading level0 col1" >target_eff</th>
#       <th id="T_a63df_level0_col2" class="col_heading level0 col2" >CF_realized</th>
# ...

# %% [markdown]
# ## 23. Performance — MV05

# %% [markdown]
# > ### Interrogation C (part 1/2) — "Decarbonization is free" for MV: true here, but partly a regional artifact
# >
# > Expected output: MV(0.5) Sharpe 0.217 vs MV 0.218 — essentially **zero Sharpe cost** for halving the carbon footprint.
# >
# > **Why this looks too good to be true:**
# > - The heaviest EUR carbon emitters (Holcim, RWE, Heidelberg, Buzzi) have **near-zero MV weights to begin with** — they're high-vol, so MV already excludes them.
# > - The 50% CF cut is therefore satisfied by minor reweighting among already-low-emission defensive names.
# >
# > **Honest framing for the report and for the sales pitch (deliverable #2):**
# > - In Europe, this conclusion is genuine.
# > - The same exercise on a North American (oil & gas heavyweights) or Asian (steel, cement) universe would likely show real cost.
# > - **Don't generalize beyond the EUR sample without saying so.**

# %%
stats_mv05 = pd.DataFrame([
    compute_perf(rp_mv, rf_mon, "P^(mv)_oos"),
    compute_perf(rp_mv05, rf_mon, "P^(mv)_oos(0.5)"),
    compute_perf(rp_vw, rf_mon, "P^(vw) (benchmark)"),
]).set_index("Portfolio")
display(stats_mv05.style
        .set_caption("Section 3.2 — Performance: MV vs MV(0.5) vs VW")
        .format({"Ann. Return Arith. (%)": "{:.2f}", "Ann. Return Geom. (%)": "{:.2f}",
                 "Ann. Vol (%)": "{:.2f}", "Sharpe": "{:.3f}",
                 "Min Mo. (%)": "{:.2f}", "Max Mo. (%)": "{:.2f}", "Max DD (%)": "{:.2f}"})
        .highlight_min(subset=["Ann. Vol (%)","Max DD (%)"], color="#c6efce")
        .highlight_max(subset=["Sharpe","Ann. Return Arith. (%)"], color="#ffeb9c")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_17652 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_17652_row1_col2, #T_17652_row2_col6 {
#   background-color: #c6efce;
# }
# #T_17652_row2_col0, #T_17652_row2_col3 {
#   background-color: #ffeb9c;
# }
# </style>
# <table id="T_17652">
#   <caption>Section 3.2 — Performance: MV vs MV(0.5) vs VW</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17652_level0_col0" class="col_heading level0 col0" >Ann. Return Arith. (%)</th>
#       <th id="T_17652_level0_col1" class="col_heading level0 col1" >Ann. Return Geom. (%)</th>
#       <th id="T_17652_level0_col2" class="col_heading level0 col2" >Ann. Vol (%)</th>
#       <th id="T_17652_level0_col3" class="col_heading level0 col3" >Sharpe</th>
#       <th id="T_17652_level0_col4" class="col_heading level0 col4" >Min Mo. (%)</th>
#       <th id="T_17652_level0_col5" class="col_heading level0 col5" >Max Mo. (%)</th>
# ...

# %% [markdown]
# ## 23. Composition Shifts — MV05 vs MV

# %%
# Composition shifts: MV(0.5) vs MV
def composition_diff_df(Y, top_n=5):
    w_mv  = mv_w_dict[Y].reindex(universe[Y]).fillna(0.0)
    w_mv5 = mv05_w_dict[Y].reindex(universe[Y]).fillna(0.0)
    diff = (w_mv5 - w_mv).sort_values()
    rows = []
    for isin, dlt in list(diff.head(top_n).items()) + list(diff.tail(top_n).iloc[::-1].items()):
        ci_val = float(co2_tot.loc[isin, Y] / rev_m.loc[isin, Y]) if (
            isin in co2_tot.index and isin in rev_m.index and
            Y in co2_tot.columns and Y in rev_m.columns and
            rev_m.loc[isin, Y] > 0) else float("nan")
        rows.append({"Name": isin_name.get(isin, isin)[:40],
                     "Direction": "Removed ↓" if dlt < 0 else "Added ↑",
                     "Δ Weight (pp)": round(dlt * 100, 2),
                     "CI (tCO₂/M$rev)": round(ci_val, 1) if not pd.isna(ci_val) else "n/a"})
    return pd.DataFrame(rows)

def _direction_color(v):
    if v == "Removed ↓":
        return "color:#c0392b;font-weight:bold"
    elif v == "Added ↑":
        return "color:#1a6b1a;font-weight:bold"
    return ""

for Y in snapshot_years:
    _df = composition_diff_df(Y)
    display(_df.style
              .set_caption(f"Y={Y} — Portfolio tilt: MV(0.5) vs MV (top 5 removed / added)")
              .hide(axis="index")
              .format({"Δ Weight (pp)": "{:+.2f}"})
              .map(_direction_color, subset=["Direction"])
              .set_table_styles([{"selector": "caption",
                                  "props": [("font-weight", "bold"), ("font-size", "13px")]}]))
# Out:
# <style type="text/css">
# #T_638aa caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_638aa_row0_col1, #T_638aa_row1_col1, #T_638aa_row2_col1, #T_638aa_row3_col1, #T_638aa_row4_col1 {
#   color: #c0392b;
#   font-weight: bold;
# }
# #T_638aa_row5_col1, #T_638aa_row6_col1, #T_638aa_row7_col1, #T_638aa_row8_col1, #T_638aa_row9_col1 {
#   color: #1a6b1a;
#   font-weight: bold;
# }
# </style>
# <table id="T_638aa">
#   <caption>Y=2013 — Portfolio tilt: MV(0.5) vs MV (top 5 removed / added)</caption>
#   <thead>
#     <tr>
#       <th id="T_638aa_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_638aa_level0_col1" class="col_heading level0 col1" >Direction</th>
#       <th id="T_638aa_level0_col2" class="col_heading level0 col2" >Δ Weight (pp)</th>
#       <th id="T_638aa_level0_col3" class="col_heading level0 col3" >CI (tCO₂/M$rev)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## 25. Plots — Section 3.2

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 9))
fig.suptitle("Section 3.2 — Min-Var vs Min-Var(0.5)", fontsize=13, fontweight="bold")
C1, C2, C3 = "steelblue", "crimson", "darkorange"
fmt = mdates.DateFormatter("%Y")
loc = mdates.YearLocator(2)

ax = axes[0, 0]
for rp, color, ls, lab in [(rp_mv, C1, "-", r"MV $P^{(mv)}_{oos}$"),
                           (rp_mv05, C2, "-", r"MV(0.5) $P^{(mv)}_{oos}(0.5)$"),
                           (rp_vw, C3, "--", r"VW $P^{(vw)}$")]:
    cum = (1 + rp.dropna()).cumprod()
    ax.plot(cum.index, cum.values, color=color, ls=ls, lw=1.8, label=lab)
ax.set_title("Cumulative Return (base=1, Jan 2014)")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[0, 1]


def dd(rp):
    c = (1 + rp.dropna()).cumprod()
    return (c - c.cummax()) / c.cummax() * 100


ax.fill_between(dd(rp_mv).index, dd(rp_mv).values, 0, alpha=0.45, color=C1, label="MV")
ax.fill_between(dd(rp_mv05).index, dd(rp_mv05).values, 0, alpha=0.45, color=C2, label="MV(0.5)")
ax.set_title("Drawdown from Peak (%)")
ax.set_ylabel("Drawdown (%)")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[1, 0]
ax.plot(mv_carbon.index, mv_carbon["WACI"], "o-", color=C1, label="MV")
ax.plot(mv05_carbon.index, mv05_carbon["WACI"], "s-", color=C2, label="MV(0.5)")
ax.plot(vw_carbon.index, vw_carbon["WACI"], "x--", color=C3, label="VW")
ax.set_title("WACI evolution")
ax.set_ylabel("tCO₂ / M$ rev")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

ax = axes[1, 1]
ax.plot(mv_carbon.index, mv_carbon["CF"], "o-", color=C1, label="MV")
ax.plot(mv05_carbon.index, mv05_carbon["CF"], "s-", color=C2, label="MV(0.5)")
ax.plot(cf_target_mv.index, cf_target_mv.values, "k:", lw=1, label="0.5×CF(MV) target")
ax.plot(vw_carbon.index, vw_carbon["CF"], "x--", color=C3, label="VW")
ax.set_title("CF evolution + 50% target")
ax.set_ylabel("tCO₂ / M$ inv")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.tight_layout()
plt.savefig(f"{OUT}SAAM_Part2_section32.pdf", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Section 3.3 — Passive Investor: TE-Min with CF ≤ 0.5 × CF(VW)

# %% [markdown]
# ## 26. CF Targets for VW

# %%
cf_target_vw = (vw_carbon["CF"] * 0.5).rename("target_CF").copy()

adj_targets_vw = {}
relax_log_vw05 = []
for Y in years:
    cf_min = get_min_cf(Y)
    target_raw = float(cf_target_vw.loc[Y])
    if cf_min > target_raw:
        adj_targets_vw[Y] = cf_min * 1.001
        relax_log_vw05.append({"Y": Y, "raw_target": target_raw,
                                "cf_min_universe": cf_min,
                                "effective_target": adj_targets_vw[Y],
                                "status": "RELAXED"})
    else:
        adj_targets_vw[Y] = target_raw
        relax_log_vw05.append({"Y": Y, "raw_target": target_raw,
                                "cf_min_universe": cf_min,
                                "effective_target": adj_targets_vw[Y],
                                "status": "feasible"})

_relax_df_vw = pd.DataFrame(relax_log_vw05).set_index("Y")
n_relaxed_vw = int((_relax_df_vw["status"] == "RELAXED").sum())
display(_relax_df_vw.style
        .set_caption(f"VW(0.5) — Target feasibility: {n_relaxed_vw}/{len(years)} years required relaxation.")
        .format({"raw_target": "{:.3f}", "cf_min_universe": "{:.3f}",
                 "effective_target": "{:.3f}"})
        .map(lambda v: "background-color:#ffd5d5" if v == "RELAXED" else "",
             subset=["status"])
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_f0cc9 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_f0cc9">
#   <caption>VW(0.5) — Target feasibility: 0/12 years required relaxation.</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0cc9_level0_col0" class="col_heading level0 col0" >raw_target</th>
#       <th id="T_f0cc9_level0_col1" class="col_heading level0 col1" >cf_min_universe</th>
#       <th id="T_f0cc9_level0_col2" class="col_heading level0 col2" >effective_target</th>
#       <th id="T_f0cc9_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Y</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## 27. TE-Min Optimizer with CF Constraint

# %%
def min_te_cf_constrained(Sigma, w_bench, c, target, isins):
    N = Sigma.shape[0]
    valid = np.isfinite(c)
    invalid = ~valid
    w0 = w_bench.copy()
    w0[invalid] = 0.0
    s = w0.sum()
    w0 = w0 / s if s > 0 else np.where(valid, 1.0, 0.0) / max(valid.sum(), 1)

    bounds = [(0.0, 0.0) if invalid[i] else (0.0, 1.0) for i in range(N)]
    c_safe = np.where(valid, c, 0.0)
    constraints = [
        {"type": "eq", "fun": lambda w: w.sum() - 1.0, "jac": lambda w: np.ones(N)},
        {"type": "ineq", "fun": lambda w: target - c_safe @ w, "jac": lambda w: -c_safe},
    ]
    return minimize(
        fun=lambda w: float((w - w_bench) @ Sigma @ (w - w_bench)),
        x0=w0, jac=lambda w: 2.0 * (Sigma @ (w - w_bench)),
        method="SLSQP", bounds=bounds, constraints=constraints,
        options={"ftol": 1e-10, "maxiter": 3000},
    )

# %% [markdown]
# ## 28. Rolling VW(0.5) Optimization

# %%
vw05_w_dict = {}
vw05_ret = {}
_vw05_diag = []

for Y in years:
    eligible = universe[Y]
    target = adj_targets_vw[Y]
    _, Sig = get_cov(Y)
    c, valid = cf_vector(eligible, Y)
    w_bench = vw_weights(Y).reindex(eligible).fillna(0.0).values

    # Check bench feasibility (it usually isn't — VW violates its own 50% constraint)
    cf_bench = float(np.where(valid, c, 0.0) @ w_bench)
    bench_feasible = cf_bench <= target

    res = min_te_cf_constrained(Sig, w_bench, c, target, eligible)
    w_raw = np.asarray(res.x, dtype=float)
    cf_raw  = float(np.where(valid, c, 0.0) @ w_raw)
    sum_raw = float(w_raw.sum())

    w = np.clip(w_raw, 0.0, 1.0)
    if w.sum() > 0:
        w /= w.sum()
    cf_renorm = float(np.where(valid, c, 0.0) @ w)

    _vw05_diag.append({
        "Y": Y, "converged": bool(res.success),
        "iter": int(getattr(res, "nit", -1)),
        "bench_feasible": bench_feasible,
        "sum(w_raw)-1": sum_raw - 1.0,
        "CF_raw": cf_raw, "CF_renorm": cf_renorm,
        "target": target,
        "CF_violation_renorm": max(cf_renorm - target, 0.0),
    })

    vw05_w_dict[Y] = pd.Series(w, index=eligible)

    R_next = get_oos_returns(Y)
    next_months = _months_of[Y + 1]
    ww = w.copy()
    port_ret = []
    for t in next_months:
        r_t = R_next[t].values
        rp_t = float(ww @ r_t)
        port_ret.append(rp_t)
        ww = ww * (1.0 + r_t) / max(1.0 + rp_t, 1e-12)
    vw05_ret[Y + 1] = pd.Series(port_ret, index=next_months)

rp_vw05 = pd.concat(vw05_ret).droplevel(0).sort_index()
rp_vw05.index = pd.DatetimeIndex(rp_vw05.index)

_diag_vw05 = pd.DataFrame(_vw05_diag).set_index("Y")
n_fail = int((~_diag_vw05["converged"]).sum())
max_viol = float(_diag_vw05["CF_violation_renorm"].max())
print(f"VW(0.5) — SLSQP failures: {n_fail}/{len(years)} | "
      f"max post-renorm CF violation: {max_viol:.4g} | "
      f"bench infeasible (expected) in {int((~_diag_vw05['bench_feasible']).sum())}/{len(years)} years")
display(_diag_vw05.style
        .set_caption("VW(0.5) — Per-year optimizer diagnostics")
        .format({"sum(w_raw)-1": "{:+.2e}",
                 "CF_raw": "{:.3f}", "CF_renorm": "{:.3f}", "target": "{:.3f}",
                 "CF_violation_renorm": "{:.2e}"})
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# VW(0.5) — SLSQP failures: 0/12 | max post-renorm CF violation: 1.421e-14 | bench infeasible (expected) in 12/12 years
# <style type="text/css">
# #T_0bc67 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_0bc67">
#   <caption>VW(0.5) — Per-year optimizer diagnostics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bc67_level0_col0" class="col_heading level0 col0" >converged</th>
#       <th id="T_0bc67_level0_col1" class="col_heading level0 col1" >iter</th>
#       <th id="T_0bc67_level0_col2" class="col_heading level0 col2" >bench_feasible</th>
#       <th id="T_0bc67_level0_col3" class="col_heading level0 col3" >sum(w_raw)-1</th>
#       <th id="T_0bc67_level0_col4" class="col_heading level0 col4" >CF_raw</th>
#       <th id="T_0bc67_level0_col5" class="col_heading level0 col5" >CF_renorm</th>
#       <th id="T_0bc67_level0_col6" class="col_heading level0 col6" >target</th>
# ...

# %% [markdown]
# ## 29. Verification — VW05

# %%
vw05_carbon = pd.DataFrame(
    [{"Y": Y, **carbon_metrics(vw05_w_dict[Y], Y)} for Y in years]
).set_index("Y")
cf_check_vw = pd.DataFrame({
    "raw_target_0.5xVW": cf_target_vw,
    "target_eff": pd.Series(adj_targets_vw),
    "CF_realized": vw05_carbon["CF"],
})
cf_check_vw["slack_vs_eff"]   = cf_check_vw["target_eff"] - cf_check_vw["CF_realized"]
cf_check_vw["pct_of_VW_base"] = (cf_check_vw["CF_realized"] / vw_carbon["CF"]) * 100
cf_check_vw["status"] = np.where(
    cf_check_vw["raw_target_0.5xVW"] < cf_check_vw["target_eff"] - 1e-9, "RELAXED", "OK")

display(cf_check_vw.style
        .set_caption("VW(0.5) — CF realized vs original (0.5xVW) target")
        .format({"raw_target_0.5xVW": "{:.3f}",
                 "target_eff": "{:.3f}",
                 "CF_realized": "{:.3f}",
                 "slack_vs_eff": "{:+.3f}",
                 "pct_of_VW_base": "{:.1f}%"})
        .map(lambda v: "background-color:#ffd5d5" if v == "RELAXED" else "",
             subset=["status"])
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_0341b caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_0341b">
#   <caption>VW(0.5) — CF realized vs original (0.5xVW) target</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0341b_level0_col0" class="col_heading level0 col0" >raw_target_0.5xVW</th>
#       <th id="T_0341b_level0_col1" class="col_heading level0 col1" >target_eff</th>
#       <th id="T_0341b_level0_col2" class="col_heading level0 col2" >CF_realized</th>
#       <th id="T_0341b_level0_col3" class="col_heading level0 col3" >slack_vs_eff</th>
#       <th id="T_0341b_level0_col4" class="col_heading level0 col4" >pct_of_VW_base</th>
#       <th id="T_0341b_level0_col5" class="col_heading level0 col5" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0341b_level0_row0" class="row_heading level0 row0" >2013</th>
#       <td id="T_0341b_row0_col0" class="data row0 col0" >106.529</td>
# ...

# %% [markdown]
# ## 30. Performance — VW05

# %% [markdown]
# > ### Interrogation C (part 2/2) — VW(0.5) cost is small but non-zero
# >
# > Expected output: VW(0.5) Sharpe 0.381 vs VW 0.406 — about **6% Sharpe reduction** for halving CF.
# > In return terms: arithmetic return drops 8.19% → 7.86% (~33 bps/yr).
# >
# > **Same regional reason as MV(0.5):** even Holcim, the largest EUR emitter, is only ~0.36% of EUR market cap. So a 50% CF cut requires only modest reweighting away from a few names — not a sector-level overhaul.
# >

# %%
stats_vw05 = pd.DataFrame([
    compute_perf(rp_vw, rf_mon, "P^(vw) (benchmark)"),
    compute_perf(rp_vw05, rf_mon, "P^(vw)_oos(0.5)"),
    compute_perf(rp_mv05, rf_mon, "P^(mv)_oos(0.5) [reference]"),
]).set_index("Portfolio")
display(stats_vw05.style
        .set_caption("Section 3.3 — Performance: VW vs VW(0.5) vs MV(0.5)")
        .format({"Ann. Return Arith. (%)": "{:.2f}", "Ann. Return Geom. (%)": "{:.2f}",
                 "Ann. Vol (%)": "{:.2f}", "Sharpe": "{:.3f}",
                 "Min Mo. (%)": "{:.2f}", "Max Mo. (%)": "{:.2f}", "Max DD (%)": "{:.2f}"})
        .highlight_min(subset=["Ann. Vol (%)","Max DD (%)"], color="#c6efce")
        .highlight_max(subset=["Sharpe","Ann. Return Arith. (%)"], color="#ffeb9c")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_7268b caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_7268b_row0_col0, #T_7268b_row0_col3 {
#   background-color: #ffeb9c;
# }
# #T_7268b_row0_col6, #T_7268b_row2_col2 {
#   background-color: #c6efce;
# }
# </style>
# <table id="T_7268b">
#   <caption>Section 3.3 — Performance: VW vs VW(0.5) vs MV(0.5)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7268b_level0_col0" class="col_heading level0 col0" >Ann. Return Arith. (%)</th>
#       <th id="T_7268b_level0_col1" class="col_heading level0 col1" >Ann. Return Geom. (%)</th>
#       <th id="T_7268b_level0_col2" class="col_heading level0 col2" >Ann. Vol (%)</th>
#       <th id="T_7268b_level0_col3" class="col_heading level0 col3" >Sharpe</th>
#       <th id="T_7268b_level0_col4" class="col_heading level0 col4" >Min Mo. (%)</th>
#       <th id="T_7268b_level0_col5" class="col_heading level0 col5" >Max Mo. (%)</th>
# ...

# %% [markdown]
# ## 31. Plots — Section 3.3

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 9))
fig.suptitle("Section 3.3 — VW vs VW(0.5)", fontsize=13, fontweight="bold")
C_VW, C_VW5, C_MV5 = "darkorange", "seagreen", "crimson"

ax = axes[0, 0]
for rp, color, ls, lab in [
    (rp_vw, C_VW, "--", r"VW $P^{(vw)}$"),
    (rp_vw05, C_VW5, "-", r"VW(0.5) $P^{(vw)}_{oos}(0.5)$"),
    (rp_mv05, C_MV5, ":", r"MV(0.5) [ref]"),
]:
    cum = (1 + rp.dropna()).cumprod()
    ax.plot(cum.index, cum.values, color=color, ls=ls, lw=1.8, label=lab)
ax.set_title("Cumulative Return (base=1, Jan 2014)")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[0, 1]
ar = (rp_vw05 - rp_vw).dropna()
te_ep = ar.std() * np.sqrt(12) * 100
ir = ar.mean() * 12 / (ar.std() * np.sqrt(12)) if ar.std() > 0 else np.nan
ar_cum = (1 + ar).cumprod()
ax.plot(ar_cum.index, (ar_cum - 1) * 100, color=C_VW5, lw=1.5)
ax.axhline(0, color="k", lw=0.6)
ax.set_title(f"Cumulative active return: VW(0.5) − VW (IR={ir:.2f})")
ax.set_ylabel("Cumulative active return (%)")
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[1, 0]
ax.plot(vw_carbon.index, vw_carbon["WACI"], "x--", color=C_VW, label="VW")
ax.plot(vw05_carbon.index, vw05_carbon["WACI"], "s-", color=C_VW5, label="VW(0.5)")
ax.set_title("WACI evolution")
ax.set_ylabel("tCO₂ / M$ rev")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

ax = axes[1, 1]
ax.plot(vw_carbon.index, vw_carbon["CF"], "x--", color=C_VW, label="VW")
ax.plot(vw05_carbon.index, vw05_carbon["CF"], "s-", color=C_VW5, label="VW(0.5)")
ax.plot(cf_target_vw.index, cf_target_vw.values, "k:", lw=1, label="0.5×CF(VW) target")
ax.set_title("CF evolution + 50% target")
ax.set_ylabel("tCO₂ / M$ inv")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

plt.tight_layout()
plt.tight_layout()
plt.savefig(f"{OUT}SAAM_Part2_section33.pdf", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Section 4.1 — Net-Zero Glide Path

# %% [markdown]
# ## 32. NZ Target Calculation

# %%
THETA = 0.10
CF_VW_2013 = float(vw_carbon.loc[2013, "CF"])


def nz_target(Y):
    return (1.0 - THETA) ** (Y - 2013 + 1) * CF_VW_2013


cf_target_nz = pd.Series({Y: nz_target(Y) for Y in years}, name="target_CF")

adj_targets_nz = {}
relax_log_nz = []
for Y in years:
    cf_min = get_min_cf(Y)
    target_raw = float(cf_target_nz.loc[Y])
    if cf_min > target_raw:
        adj_targets_nz[Y] = cf_min * 1.001
        relax_log_nz.append({"Y": Y, "raw_target_glide": target_raw,
                              "cf_min_universe": cf_min,
                              "effective_target": adj_targets_nz[Y],
                              "status": "RELAXED"})
    else:
        adj_targets_nz[Y] = target_raw
        relax_log_nz.append({"Y": Y, "raw_target_glide": target_raw,
                              "cf_min_universe": cf_min,
                              "effective_target": adj_targets_nz[Y],
                              "status": "feasible"})

_relax_df_nz = pd.DataFrame(relax_log_nz).set_index("Y")
n_relaxed_nz = int((_relax_df_nz["status"] == "RELAXED").sum())
display(_relax_df_nz.style
        .set_caption(
            f"VW(NZ) — Glide-path feasibility (theta={THETA:.0%}, CF_2013={CF_VW_2013:.2f}): "
            f"{n_relaxed_nz}/{len(years)} years pinned at universe floor. "
            f"Where status=RELAXED, the NZ glide path is infeasible — realized reduction "
            f"falls short of (1-theta)^(Y-2013+1).")
        .format({"raw_target_glide": "{:.3f}",
                 "cf_min_universe": "{:.3f}",
                 "effective_target": "{:.3f}"})
        .map(lambda v: "background-color:#ffd5d5" if v == "RELAXED" else "",
             subset=["status"])
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_7d62e caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_7d62e">
#   <caption>VW(NZ) — Glide-path feasibility (theta=10%, CF_2013=213.06): 0/12 years pinned at universe floor. Where status=RELAXED, the NZ glide path is infeasible — realized reduction falls short of (1-theta)^(Y-2013+1).</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d62e_level0_col0" class="col_heading level0 col0" >raw_target_glide</th>
#       <th id="T_7d62e_level0_col1" class="col_heading level0 col1" >cf_min_universe</th>
#       <th id="T_7d62e_level0_col2" class="col_heading level0 col2" >effective_target</th>
#       <th id="T_7d62e_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Y</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# ## 33. Rolling VW(NZ) Optimization

# %%
vwnz_w_dict = {}
vwnz_ret = {}
_vwnz_diag = []

for Y in years:
    eligible = universe[Y]
    target = adj_targets_nz[Y]
    _, Sig = get_cov(Y)
    c, valid = cf_vector(eligible, Y)
    w_bench = vw_weights(Y).reindex(eligible).fillna(0.0).values

    res = min_te_cf_constrained(Sig, w_bench, c, target, eligible)
    w_raw = np.asarray(res.x, dtype=float)
    cf_raw  = float(np.where(valid, c, 0.0) @ w_raw)
    sum_raw = float(w_raw.sum())

    w = np.clip(w_raw, 0.0, 1.0)
    if w.sum() > 0:
        w /= w.sum()
    cf_renorm = float(np.where(valid, c, 0.0) @ w)

    _vwnz_diag.append({
        "Y": Y, "converged": bool(res.success),
        "iter": int(getattr(res, "nit", -1)),
        "sum(w_raw)-1": sum_raw - 1.0,
        "CF_raw": cf_raw, "CF_renorm": cf_renorm,
        "target": target,
        "CF_violation_renorm": max(cf_renorm - target, 0.0),
    })

    vwnz_w_dict[Y] = pd.Series(w, index=eligible)

    R_next = get_oos_returns(Y)
    next_months = _months_of[Y + 1]
    ww = w.copy()
    port_ret = []
    for t in next_months:
        r_t = R_next[t].values
        rp_t = float(ww @ r_t)
        port_ret.append(rp_t)
        ww = ww * (1.0 + r_t) / max(1.0 + rp_t, 1e-12)
    vwnz_ret[Y + 1] = pd.Series(port_ret, index=next_months)

rp_vwnz = pd.concat(vwnz_ret).droplevel(0).sort_index()
rp_vwnz.index = pd.DatetimeIndex(rp_vwnz.index)

_diag_vwnz = pd.DataFrame(_vwnz_diag).set_index("Y")
n_fail = int((~_diag_vwnz["converged"]).sum())
max_viol = float(_diag_vwnz["CF_violation_renorm"].max())
print(f"VW(NZ) — SLSQP failures: {n_fail}/{len(years)} | "
      f"max post-renorm CF violation: {max_viol:.4g}")
display(_diag_vwnz.style
        .set_caption("VW(NZ) — Per-year optimizer diagnostics")
        .format({"sum(w_raw)-1": "{:+.2e}",
                 "CF_raw": "{:.3f}", "CF_renorm": "{:.3f}", "target": "{:.3f}",
                 "CF_violation_renorm": "{:.2e}"})
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# VW(NZ) — SLSQP failures: 0/12 | max post-renorm CF violation: 4.263e-14
# <style type="text/css">
# #T_40ffa caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_40ffa">
#   <caption>VW(NZ) — Per-year optimizer diagnostics</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40ffa_level0_col0" class="col_heading level0 col0" >converged</th>
#       <th id="T_40ffa_level0_col1" class="col_heading level0 col1" >iter</th>
#       <th id="T_40ffa_level0_col2" class="col_heading level0 col2" >sum(w_raw)-1</th>
#       <th id="T_40ffa_level0_col3" class="col_heading level0 col3" >CF_raw</th>
#       <th id="T_40ffa_level0_col4" class="col_heading level0 col4" >CF_renorm</th>
#       <th id="T_40ffa_level0_col5" class="col_heading level0 col5" >target</th>
#       <th id="T_40ffa_level0_col6" class="col_heading level0 col6" >CF_violation_renorm</th>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## 34. Verification — VWNZ

# %%
vwnz_carbon = pd.DataFrame(
    [{"Y": Y, **carbon_metrics(vwnz_w_dict[Y], Y)} for Y in years]
).set_index("Y")
cf_check_nz = pd.DataFrame({
    "glide_target": cf_target_nz,
    "target_eff": pd.Series(adj_targets_nz),
    "CF_realized": vwnz_carbon["CF"],
})
cf_check_nz["pct_of_2013_CF"]    = vwnz_carbon["CF"] / CF_VW_2013 * 100
cf_check_nz["theoretical_pct"]   = ((1.0 - THETA) ** (cf_check_nz.index - 2013 + 1)) * 100
cf_check_nz["shortfall_vs_glide"] = cf_check_nz["pct_of_2013_CF"] - cf_check_nz["theoretical_pct"]
cf_check_nz["status"] = np.where(
    cf_check_nz["glide_target"] < cf_check_nz["target_eff"] - 1e-9, "RELAXED", "OK")

display(cf_check_nz.style
        .set_caption("VW(NZ) — Realized CF vs glide-path target. "
                     "shortfall_vs_glide>0 means the portfolio missed the theoretical (1-theta)^k path "
                     "(typically because the universe floor blocks further reduction).")
        .format({"glide_target": "{:.3f}",
                 "target_eff": "{:.3f}",
                 "CF_realized": "{:.3f}",
                 "pct_of_2013_CF": "{:.1f}%",
                 "theoretical_pct": "{:.1f}%",
                 "shortfall_vs_glide": "{:+.2f} pp"})
        .map(lambda v: "background-color:#ffd5d5" if v == "RELAXED" else "",
             subset=["status"])
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_d4b30 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_d4b30">
#   <caption>VW(NZ) — Realized CF vs glide-path target. shortfall_vs_glide>0 means the portfolio missed the theoretical (1-theta)^k path (typically because the universe floor blocks further reduction).</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4b30_level0_col0" class="col_heading level0 col0" >glide_target</th>
#       <th id="T_d4b30_level0_col1" class="col_heading level0 col1" >target_eff</th>
#       <th id="T_d4b30_level0_col2" class="col_heading level0 col2" >CF_realized</th>
#       <th id="T_d4b30_level0_col3" class="col_heading level0 col3" >pct_of_2013_CF</th>
#       <th id="T_d4b30_level0_col4" class="col_heading level0 col4" >theoretical_pct</th>
#       <th id="T_d4b30_level0_col5" class="col_heading level0 col5" >shortfall_vs_glide</th>
# ...

# %% [markdown]
# ## 35. Performance — All Passive

# %%
stats_nz = pd.DataFrame([
    compute_perf(rp_vw, rf_mon, "P^(vw)"),
    compute_perf(rp_vw05, rf_mon, "P^(vw)_oos(0.5)"),
    compute_perf(rp_vwnz, rf_mon, "P^(vw)_oos(NZ)"),
]).set_index("Portfolio")
display(stats_nz.style
        .set_caption("Section 4.1 — Performance: VW vs VW(0.5) vs VW(NZ)")
        .format({"Ann. Return Arith. (%)": "{:.2f}", "Ann. Return Geom. (%)": "{:.2f}",
                 "Ann. Vol (%)": "{:.2f}", "Sharpe": "{:.3f}",
                 "Min Mo. (%)": "{:.2f}", "Max Mo. (%)": "{:.2f}", "Max DD (%)": "{:.2f}"})
        .highlight_min(subset=["Ann. Vol (%)","Max DD (%)"], color="#c6efce")
        .highlight_max(subset=["Sharpe","Ann. Return Arith. (%)"], color="#ffeb9c")
        .set_table_styles([{"selector":"caption","props":[("font-weight","bold"),("font-size","13px")]}]))
# Out:
# <style type="text/css">
# #T_6c29f caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# #T_6c29f_row0_col0, #T_6c29f_row0_col3 {
#   background-color: #ffeb9c;
# }
# #T_6c29f_row0_col2, #T_6c29f_row0_col6 {
#   background-color: #c6efce;
# }
# </style>
# <table id="T_6c29f">
#   <caption>Section 4.1 — Performance: VW vs VW(0.5) vs VW(NZ)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c29f_level0_col0" class="col_heading level0 col0" >Ann. Return Arith. (%)</th>
#       <th id="T_6c29f_level0_col1" class="col_heading level0 col1" >Ann. Return Geom. (%)</th>
#       <th id="T_6c29f_level0_col2" class="col_heading level0 col2" >Ann. Vol (%)</th>
#       <th id="T_6c29f_level0_col3" class="col_heading level0 col3" >Sharpe</th>
#       <th id="T_6c29f_level0_col4" class="col_heading level0 col4" >Min Mo. (%)</th>
#       <th id="T_6c29f_level0_col5" class="col_heading level0 col5" >Max Mo. (%)</th>
# ...

# %% [markdown]
# ## 36. Plots — Section 4.1

# %%
fig, axes = plt.subplots(2, 2, figsize=(14, 9))
fig.suptitle("Section 4.1 — VW vs VW(0.5) vs VW(NZ)", fontsize=13, fontweight="bold")
C_VW, C_VW5, C_NZ = "darkorange", "seagreen", "purple"

ax = axes[0, 0]
for rp, color, ls, lab in [
    (rp_vw, C_VW, "--", r"VW $P^{(vw)}$"),
    (rp_vw05, C_VW5, "-", r"VW(0.5)"),
    (rp_vwnz, C_NZ, "-", r"VW(NZ)"),
]:
    cum = (1 + rp.dropna()).cumprod()
    ax.plot(cum.index, cum.values, color=color, ls=ls, lw=1.8, label=lab)
ax.set_title("Cumulative Return (base=1)")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

ax = axes[0, 1]
ax.plot(vw_carbon.index, vw_carbon["CF"], "x--", color=C_VW, label="VW CF")
ax.plot(vw05_carbon.index, vw05_carbon["CF"], "s-", color=C_VW5, label="VW(0.5) CF")
ax.plot(vwnz_carbon.index, vwnz_carbon["CF"], "o-", color=C_NZ, label="VW(NZ) CF")
ax.plot(cf_target_nz.index, cf_target_nz.values, ":", color=C_NZ, lw=1, label="NZ target")
ax.plot(cf_target_vw.index, cf_target_vw.values, ":", color=C_VW5, lw=1, label="0.5×VW target")
ax.set_title("CF evolution + glide paths")
ax.set_ylabel("tCO₂ / M$ inv")
ax.legend(fontsize=8)
ax.grid(alpha=0.3)

ax = axes[1, 0]
ax.plot(vw_carbon.index, vw_carbon["WACI"], "x--", color=C_VW, label="VW")
ax.plot(vw05_carbon.index, vw05_carbon["WACI"], "s-", color=C_VW5, label="VW(0.5)")
ax.plot(vwnz_carbon.index, vwnz_carbon["WACI"], "o-", color=C_NZ, label="VW(NZ)")
ax.set_title("WACI evolution")
ax.set_ylabel("tCO₂ / M$ rev")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)

ax = axes[1, 1]
ar05_cum = (1 + (rp_vw05 - rp_vw).dropna()).cumprod()
arnz_cum = (1 + (rp_vwnz - rp_vw).dropna()).cumprod()
ir05 = (rp_vw05 - rp_vw).mean() * 12 / ((rp_vw05 - rp_vw).std() * np.sqrt(12)) if (rp_vw05 - rp_vw).std() > 0 else np.nan
irnz = (rp_vwnz - rp_vw).mean() * 12 / ((rp_vwnz - rp_vw).std() * np.sqrt(12)) if (rp_vwnz - rp_vw).std() > 0 else np.nan
ax.plot(ar05_cum.index, (ar05_cum - 1) * 100, color=C_VW5, lw=1.5,
        label=f"VW(0.5) − VW (IR={ir05:+.2f})")
ax.plot(arnz_cum.index, (arnz_cum - 1) * 100, color=C_NZ, lw=1.5,
        label=f"VW(NZ) − VW (IR={irnz:+.2f})")
ax.axhline(0, color="k", lw=0.6)
ax.set_title("Cumulative active return vs VW")
ax.set_ylabel("Cumulative active return (%)")
ax.legend(fontsize=9)
ax.grid(alpha=0.3)
ax.xaxis.set_major_formatter(fmt)
ax.xaxis.set_major_locator(loc)

plt.tight_layout()
plt.tight_layout()
plt.savefig(f"{OUT}SAAM_Part2_section41.pdf", dpi=150, bbox_inches="tight")
plt.show()

# %%
# ─── Section 4.2 — Cost of decarbonisation vs VW benchmark ────────────────────
# The cumulative-return comparison lives in §4.1 (cell 86). Here we quantify the
# *cost* of imposing carbon constraints in standard active-risk terms.

def cost_vs_bench(rp, rb, label):
    a = (rp - rb).dropna()
    ann_active = a.mean() * 12 * 100                              # in %
    te         = a.std(ddof=1) * np.sqrt(12) * 100                # in %
    ir         = ann_active / te if te > 0 else np.nan
    t_stat     = a.mean() / (a.std(ddof=1) / np.sqrt(len(a)))      # naive (no NW)
    cum_gap    = ((1 + rp).prod() / (1 + rb.loc[a.index]).prod() - 1) * 100
    return {"Portfolio": label,
            "Ann. Active Ret. (%)":      ann_active,
            "Tracking Error (%)":        te,
            "Information Ratio":         ir,
            "t-stat (active, naive)":    t_stat,
            "Final wealth gap vs VW (%)": cum_gap,
            "N months":                  int(len(a))}

cost_tbl = pd.DataFrame([
    cost_vs_bench(rp_vw05, rp_vw, "P^(vw)_oos(0.5)"),
    cost_vs_bench(rp_vwnz, rp_vw, "P^(vw)_oos(NZ)"),
]).set_index("Portfolio")

display(cost_tbl.style
        .set_caption("Section 4.2 — Cost of decarbonisation (vs VW benchmark)")
        .format({"Ann. Active Ret. (%)": "{:+.2f}",
                 "Tracking Error (%)":   "{:.2f}",
                 "Information Ratio":    "{:+.3f}",
                 "t-stat (active, naive)": "{:+.2f}",
                 "Final wealth gap vs VW (%)": "{:+.2f}",
                 "N months": "{:d}"})
        .set_table_styles([{"selector":"caption",
                            "props":[("font-weight","bold"),("font-size","13px")]}]))

# ─── Verification ─────────────────────────────────────────────────────────────
# (V1) Wealth-gap reconciles with direct cumprod ratio.
for rp, lab in [(rp_vw05, "VW(0.5)"), (rp_vwnz, "VW(NZ)")]:
    idx = rp.dropna().index
    gap_direct = ((1 + rp.loc[idx]).prod() / (1 + rp_vw.loc[idx]).prod() - 1) * 100
    gap_table  = cost_tbl.loc[f"P^(vw)_oos({'0.5' if 'VW(0.5)' in lab else 'NZ'})",
                              "Final wealth gap vs VW (%)"]
    print(f"V1 {lab:7s}: direct={gap_direct:+.4f}%  table={gap_table:+.4f}%  "
          f"-> {np.isclose(gap_direct, gap_table)}")

# (V2) Active return ≈ geometric-return spread from stats_nz (within rounding).
geom_vw   = stats_nz.loc["P^(vw)",           "Ann. Return Geom. (%)"]
geom_vw05 = stats_nz.loc["P^(vw)_oos(0.5)",  "Ann. Return Geom. (%)"]
geom_vwnz = stats_nz.loc["P^(vw)_oos(NZ)",   "Ann. Return Geom. (%)"]
print(f"V2 Geom-return spreads: "
      f"VW(0.5)−VW={geom_vw05-geom_vw:+.2f}% | "
      f"VW(NZ)−VW={geom_vwnz-geom_vw:+.2f}%   "
      f"(should be close to arithmetic active return, but not identical: "
      f"geometric ≠ arithmetic when vols differ)")

# (V3) The NZ glide path is binding: end-2024 CF should be near (1-θ)^12 × CF_2013.
cf_end   = vwnz_carbon["CF"].iloc[-1]
cf_naive = (1 - THETA) ** (2024 - 2013 + 1) * CF_VW_2013
print(f"V3 NZ end-2024: realized CF={cf_end:.2f}  raw glide-path target={cf_naive:.2f}  "
      f"reduction vs 2013 = {(1 - cf_end / CF_VW_2013) * 100:.1f}% "
      f"(theoretical = {(1 - (1-THETA)**12) * 100:.1f}%)")
# Out:
# <style type="text/css">
# #T_b3334 caption {
#   font-weight: bold;
#   font-size: 13px;
# }
# </style>
# <table id="T_b3334">
#   <caption>Section 4.2 — Cost of decarbonisation (vs VW benchmark)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3334_level0_col0" class="col_heading level0 col0" >Ann. Active Ret. (%)</th>
#       <th id="T_b3334_level0_col1" class="col_heading level0 col1" >Tracking Error (%)</th>
#       <th id="T_b3334_level0_col2" class="col_heading level0 col2" >Information Ratio</th>
#       <th id="T_b3334_level0_col3" class="col_heading level0 col3" >t-stat (active, naive)</th>
#       <th id="T_b3334_level0_col4" class="col_heading level0 col4" >Final wealth gap vs VW (%)</th>
#       <th id="T_b3334_level0_col5" class="col_heading level0 col5" >N months</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Portfolio</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
